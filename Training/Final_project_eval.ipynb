# %%
# !pip install datasets evaluate rouge_score absl-py

from transformers import BlipProcessor, BlipForConditionalGeneration
import torch
from PIL import Image
from datasets import load_dataset, Dataset
from evaluate import load
import nltk
from itertools import islice

import os
os.environ["WANDB_DISABLED"] = "true"
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (3.5.0)
# Requirement already satisfied: evaluate in /usr/local/lib/python3.11/dist-packages (0.4.3)
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (1.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets) (2024.12.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.15)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.30.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from rouge_score) (3.9.1)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from rouge_score) (1.17.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.3.2)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.1.31)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (2024.11.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=46a34feff4da2498e63763c07113395b868c76adfaf66d8466e3aa5990fbedee
#   Stored in directory: /root/.cache/pip/wheels/1e/19/43/8a442dc83660ca25e163e1bd1f89919284ab0d0c1475475148
# Successfully built rouge_score
# Installing collected packages: rouge_score
# Successfully installed rouge_score-0.1.2

# %%
processor = BlipProcessor.from_pretrained("dmccarthy1145/BLIP-Instagram")
model = BlipForConditionalGeneration.from_pretrained("dmccarthy1145/BLIP-Instagram")

if torch.cuda.is_available():
    model.to("cuda")

ds = load_dataset("Obscure-Entropy/ImageCaptioning_SmallParquets",
                  split="train",
                  streaming=True)

# Preprocessing function
def preprocess(example):
    # Convert image to RGB in case it's not in that format
    image = example["img"].convert("RGB")
    caption = example["en_cap"]  # Get the caption text

    # Use the processor to process both image and caption
    inputs = processor(images=image, text=caption, return_tensors="pt", padding="max_length", truncation=True, max_length=64)

    # Return pixel_values (processed image tensor) and input_ids (tokenized caption)
    return {
        "pixel_values": inputs["pixel_values"].squeeze(0),  # Image tensor
        "input_ids": inputs["input_ids"].squeeze(0),        # Tokenized caption
        "labels": inputs["input_ids"].squeeze(0)            # Tokenized caption
    }

def greedy_caption(model, processor, image):
    inputs = processor(images=image, return_tensors="pt").to(model.device)

    out_greedy = model.generate(**inputs)
    return processor.decode(out_greedy[0], skip_special_tokens=True)
# Out:
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/471 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/712k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/695 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/975 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.88G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/136 [00:00<?, ?B/s]

# %%
# Load evaluation metrics
rouge = load("rouge")
bleu = load("bleu")

# Take evaluation dataset and apply preprocessing
eval_ds = list(islice(ds, 10000, 11000))
eval_dataset = [preprocess(sample) for sample in eval_ds]

print(type(eval_dataset))
# Out:
# Downloading builder script:   0%|          | 0.00/5.94k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/1.55k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/3.34k [00:00<?, ?B/s]
# <class 'list'>

# %%
predictions = []
references = []

for i, row in enumerate(eval_ds):
    image = row["img"]
    pred = greedy_caption(model, processor, image)

    predictions.append(pred)
    references.append(row["en_cap"])

    print(f"Prediction {i}/{len(eval_ds)}: {pred}")
# Out:
# Prediction 0/100: the image captures a vibrant scene at what appears to be a amusement park or amusement park. two children
# Prediction 1/100: the image captures a vibrant scene at dusk on a farm or farmyard. the house on the left
# Prediction 2/100: the image captures a close - up view of a basket filled with small fish, possibly small fish or
# Prediction 3/100: the image captures a vibrant scene inside a grocery store or grocery store. the store ' s interior is
# Prediction 4/100: the image presents a close - up view of a pile of oatmeal, which appears to
# Prediction 5/100: the image captures a moment between two individuals who are engaged in what appears to be a maternity photo or
# Prediction 6/100: the image showcases two bicycles parked side by side on a black surface at what appears to be a trade
# Prediction 7/100: the image features a man standing on a blue platform with a white background. he is dressed in a
# Prediction 8/100: the image captures a vibrant scene at a swimming pool with a clear blue sky above. the pool is
# Prediction 9/100: the image captures a man with tattoos on his arms and arms, holding a guitar, which he has
# Prediction 10/100: the image captures a lively scene at what appears to be a political event or event. in the fore
# Prediction 11/100: the image showcases a gold watch with a white leather strap, adorned with a white pearl dial and a
# Prediction 12/100: the image captures a serene scene on a river where a boat is docked on the bank, with its
# Prediction 13/100: the image captures a moment where a wheelchair with wheels is lying on a patterned surface. the wheelchair '
# Prediction 14/100: the image captures a bustling scene at what appears to be a construction site or site, possibly a
# Prediction 15/100: the image captures a busy office space with multiple desks and computers, suggesting a well - organized work
# Prediction 16/100: the image captures a moment of contemplation in a dark room with a focus on a person
# Prediction 17/100: the image captures a serene scene in a forest setting with tall trees and lush greenery. the trees
# Prediction 18/100: the image captures a vibrant city scene under a clear blue sky. the sign reads abu dhabi, which
# Prediction 19/100: the image presents a close - up view of a 100 yen banknote with a portrait of person on
# Prediction 20/100: the image features a woman with long dark hair and a neutral makeup look. she has long dark hair
# Prediction 21/100: the image captures a vibrant scene of a sunflower field with a vibrant yellow color, with a clear
# Prediction 22/100: the image showcases a heart - shaped tin box with a silver tin lid, adorned with a black and
# Prediction 23/100: the image presents a rustic scene featuring a blue bottle with a cork cap on its side, resting on
# Prediction 24/100: the image showcases a silver bracelet with a textured design on its surface. the bracelet features a silver
# Prediction 25/100: the image portrays a young woman dressed in armor with a unique design. she is holding a small object
# Prediction 26/100: the image captures a serene night scene at a beach with calm waters, reflecting the light of the moon
# Prediction 27/100: the image captures a serene outdoor setting at dusk, featuring a large dome structure with a central dome at
# Prediction 28/100: the image captures a lively scene inside a large office building with multiple desks and computers. the room
# Prediction 29/100: the image captures a bustling city scene with a bustling building with multiple balconies on its
# Prediction 30/100: the image captures a young girl holding a red apple with a green leaf on its tip, which she
# Prediction 31/100: the image captures a moment inside a car with a man smiling at the camera. he is wearing a
# Prediction 32/100: the image presents a vibrant illustration of a stylized arrow with a curved edge. the arrow ' s center
# Prediction 33/100: the image features a logo with a red triangle at the top of it. the logo is prominently displayed
# Prediction 34/100: the image presents a vibrant scene from a historical period where two men are engaged in battle, one on
# Prediction 35/100: the image portrays a man with a beard and mustache, wearing a white shirt with a collar and a
# Prediction 36/100: the image portrays a lively scene from a medieval manuscript with a central focus on a group of people,
# Prediction 37/100: the image presents three glasses filled with wine and various food items. the glasses are placed on a wooden
# Prediction 38/100: the image showcases a close - up view of a light green shirt with a collar and a button closure
# Prediction 39/100: the image portrays three women with short hair, each wearing a different hairstyle. the woman on the
# Prediction 40/100: the image captures a serene beach scene with a variety of outdoor furniture on a sandy beach. the furniture
# Prediction 41/100: the image captures a vibrant scene of a rocky outcropping under a clear blue sky. the
# Prediction 42/100: the image captures a moment on a porch where a man is seated on a step with his dog,
# Prediction 43/100: the image showcases a cozy scene featuring two owls perched on a wooden table with a gold base, positioned
# Prediction 44/100: the image features a vibrant portrait of albert einstein, the first man to be depicted on a canvas,
# Prediction 45/100: the image features a stylized logo with a stylized design featuring a cityscape with a prominent tower at
# Prediction 46/100: the image portrays a surreal scene featuring a woman standing at the entrance to a book with a golden cover
# Prediction 47/100: the image presents a collection of various items arranged on a white background. the objects are arranged in a
# Prediction 48/100: the image captures a vibrant cityscape at night, featuring a modern building with a striking architectural design
# Prediction 49/100: the image captures a serene window scene with a rustic charm. a hanging basket filled with white roses and
# Prediction 50/100: the image captures a scene inside a kitchen where two individuals are engaged in conversation. the person on the
# Prediction 51/100: the image presents a striking illustration featuring a creature with a long beard and a beard, depicted in a
# Prediction 52/100: the image captures a woman standing on a sidewalk on a rainy day. she is dressed in a dark
# Prediction 53/100: the image captures a young child standing on a carpeted floor with a focus on the camera, possibly
# Prediction 54/100: the image showcases a black jacket with a white logo on the back, placed on a wooden floor with
# Prediction 55/100: the image captures a vibrant scene at the entrance of a stadium with a large banner on it. the
# Prediction 56/100: the image showcases a close - up view of a person ' s hand holding a nail polish bottle with
# Prediction 57/100: the image presents a modern living room setting with a warm and inviting ambiance. the room features
# Prediction 58/100: the image features a logo for the pendergraft firm, real estate & business law firm,
# Prediction 59/100: the image presents a black and white illustration of a dog ' s head, which appears to be a
# Prediction 60/100: the image presents a captivating aerial view of a river flowing through a mountainous landscape with a mountainous landscape
# Prediction 61/100: the image captures a moment between two individuals on a swing at a park or garden. the person on
# Prediction 62/100: the image features a rustic wooden door with a weathered finish. the door features a weathered finish with a
# Prediction 63/100: the image presents a vibrant illustration featuring two swords with their blades positioned against a shield with a central african
# Prediction 64/100: the image captures a serene scene inside a cave with a natural setting. the cave ' s interior is
# Prediction 65/100: the image presents a vibrant scene featuring a collection of posters featuring various landmarks and landmarks. the poster features
# Prediction 66/100: the image presents a collage of two photographs featuring a man and a woman, each wearing different attire
# Prediction 67/100: the image presents a delightful scene featuring a slice of cake with a golden brown crust and a creamy white
# Prediction 68/100: the image presents a modern bathroom with a large window overlooking a lush green landscape. the window pane
# Prediction 69/100: the image presents three flags with multiple colors, each representing a different country or country. the flags are
# Prediction 70/100: the image captures a vibrant scene under a clear blue sky with no clouds. two flags are flown against
# Prediction 71/100: the image captures a scene inside a train station where two trains are parked on tracks, one on the
# Prediction 72/100: the image presents two distinct illustrations of a cow standing upright on its hind legs. the cow ' s
# Prediction 73/100: the image portrays a man with a golden crown on his head, which is adorned with a red velvet
# Prediction 74/100: the image captures a close - up view of a person holding a bouquet of flowers, which appears to
# Prediction 75/100: the image presents a cozy living room scene with a warm and inviting atmosphere. the room features a cozy
# Prediction 76/100: the image captures a lively beach scene under a clear blue sky. the beach is filled with people enjoying
# Prediction 77/100: the image portrays a young woman standing against a white background. she is dressed in a vibrant orange top
# Prediction 78/100: the image features a stylized logo with a stylized design featuring a boat at the bottom, with a blue
# Prediction 79/100: the image captures a vibrant scene on a street corner with a focus on a storefront with a yellow
# Prediction 80/100: the image captures a vibrant scene of fireworks exploding in the night sky. the fireworks are illuminated by green
# Prediction 81/100: the image captures a lively scene at a party or event. the party is filled with people dancing and
# Prediction 82/100: the image captures a vibrant cityscape with a mix of red brick buildings and white balconies
# Prediction 83/100: the image showcases a charming white house with a red, white, and green flag hanging from the front
# Prediction 84/100: the image captures a vibrant scene at a train station where a yellow train is parked on the tracks.
# Prediction 85/100: the image captures two pairs of black backpacks with straps on their handles, each carrying a backpack with
# Prediction 86/100: the image captures a moment at what appears to be a construction site or site where a man is standing
# Prediction 87/100: the image captures a serene kitchen scene with a central focus on a man and woman standing at a kitchen
# Prediction 88/100: the image showcases a close - up view of a decorative sculpture with intricate details, including intricate carvings and
# Prediction 89/100: the image captures a serene scene featuring a golf bag filled with golf balls on a grassy field. the
# Prediction 90/100: the image presents a delightful scene featuring a piece of cake with a golden crust and a drizzle
# Prediction 91/100: the image captures a close - up view of a horse ' s head with its ears turned slightly as
# Prediction 92/100: the image presents a collection of three distinct pieces of paper, each partially torn apart, revealing a distinct
# Prediction 93/100: the image presents a vibrant illustration of a heart shape with a central red border, which is filled with
# Prediction 94/100: the image portrays a vibrant scene featuring four women standing side by side against a backdrop of a blue sky
# Prediction 95/100: the image captures a serene scene featuring a large white building with columns and columns, with a statue of
# Prediction 96/100: the image presents a step - by - step guide on how to tie a pair of sneakers with lace
# Prediction 97/100: the image captures a moment where a person is engaged in pottery work. the person ' s hands are
# Prediction 98/100: the image showcases a silver jeep parked in a parking lot with a wet surface. the jeep is parked
# Prediction 99/100: the image captures a vibrant scene under a clear blue sky with scattered clouds. the signpost features multiple

# %%
# Verify references and predictions
print("References:")
print(references)

print("\nPredictions:")
print(predictions)
# Out:
# References:
# ["The image captures a lively scene at what appears to be a carnival or amusement park. Two children are seated on a vibrant green and purple ride with yellow accents. The child on the left is wearing a white shirt paired with blue shorts, while the child on the right sports a black shirt with white shorts. Both children are actively engaged with their surroundings, their arms raised high in excitement as they enjoy the ride. The ride itself is situated on a track, suggesting it's part of a larger amusement park setup. The background reveals a clear sky, indicating good weather for outdoor activities. The overall atmosphere suggests a fun and joyful day out for these two children.", "The image depicts a tranquil rural scene at dusk. A prominent blue house with white trim stands on a grassy lawn, its windows glowing with warm light. To the left of the house, there's a red barn with white doors, also illuminated from within. A black car is parked in front of the barn, adding a modern touch to the otherwise traditional setting. The sky above is painted with hues of blue, suggesting it's either dawn or dusk. The overall scene conveys a sense of calm and homely comfort.", "The image captures a scene featuring a wicker basket filled with small fish. The basket appears to be placed on a flat surface, possibly a table or countertop. The fish are scattered throughout the basket, with some lying on their sides while others are stacked on top of each other. The fish are small with a silvery color, suggesting they might be sardines or similar species. The basket has a handle on one side, indicating it's designed for carrying or serving purposes. The background is blurred but suggests an indoor setting with warm lighting.", 'The image captures a vibrant scene from a grocery store specializing in fresh and local organic produce. The store\'s interior features a variety of fruits and vegetables displayed on shelves and tables. The produce includes bananas, apples, oranges, and other fruits, as well as potatoes, onions, and other vegetables. The store\'s signage prominently displays the words "Fresh & Local Organic", indicating its commitment to providing fresh, locally sourced organic products. The lighting is bright, highlighting the freshness and quality of the produce. The store\'s design suggests a clean and inviting atmosphere for customers.', 'The image displays a close-up view of oats, which are presented in various shades of brown. The oats are scattered across the frame, with some appearing larger due to their proximity to the camera. The background is blurred but suggests a natural setting with hints of greenery. The focus of the image is on the oats themselves, which are likely intended for consumption or use in cooking. The text overlay provides nutritional information about the oats, indicating they are "Oatmeal 17g (100g) (1 cup)." The overall style of the image suggests it may be used for educational or promotional purposes related to nutrition or cooking.', 'The image captures a tender moment between two individuals who appear to be embracing each other. The person on the left is wearing a white shirt paired with dark pants, while the person on the right is dressed in a white lace dress with a sheer overlay. The background is blurred but suggests an indoor setting with soft lighting. The focus of the image is on the emotional connection between the two individuals, with their bodies close together and their faces turned towards each other, suggesting affection or intimacy.', "The image showcases a unique bicycle with striking blue wheels parked indoors. The bicycle features a silver frame with yellow accents on the handlebars and pedals. It has a black seat and black tires with white lettering on them. The bicycle is positioned on a black floor with a green carpeted area behind it. In the background, there are other bicycles and various items on display, suggesting this might be at a bike expo or similar event. The lighting i ...
#
# Predictions:
# ['the image captures a vibrant scene at what appears to be a amusement park or amusement park. two children', 'the image captures a vibrant scene at dusk on a farm or farmyard. the house on the left', 'the image captures a close - up view of a basket filled with small fish, possibly small fish or', "the image captures a vibrant scene inside a grocery store or grocery store. the store ' s interior is", 'the image presents a close - up view of a pile of oatmeal, which appears to', 'the image captures a moment between two individuals who are engaged in what appears to be a maternity photo or', 'the image showcases two bicycles parked side by side on a black surface at what appears to be a trade', 'the image features a man standing on a blue platform with a white background. he is dressed in a', 'the image captures a vibrant scene at a swimming pool with a clear blue sky above. the pool is', 'the image captures a man with tattoos on his arms and arms, holding a guitar, which he has', 'the image captures a lively scene at what appears to be a political event or event. in the fore', 'the image showcases a gold watch with a white leather strap, adorned with a white pearl dial and a', 'the image captures a serene scene on a river where a boat is docked on the bank, with its', "the image captures a moment where a wheelchair with wheels is lying on a patterned surface. the wheelchair '", 'the image captures a bustling scene at what appears to be a construction site or site, possibly a', 'the image captures a busy office space with multiple desks and computers, suggesting a well - organized work', 'the image captures a moment of contemplation in a dark room with a focus on a person', 'the image captures a serene scene in a forest setting with tall trees and lush greenery. the trees', 'the image captures a vibrant city scene under a clear blue sky. the sign reads abu dhabi, which', 'the image presents a close - up view of a 100 yen banknote with a portrait of person on', 'the image features a woman with long dark hair and a neutral makeup look. she has long dark hair', 'the image captures a vibrant scene of a sunflower field with a vibrant yellow color, with a clear', 'the image showcases a heart - shaped tin box with a silver tin lid, adorned with a black and', 'the image presents a rustic scene featuring a blue bottle with a cork cap on its side, resting on', 'the image showcases a silver bracelet with a textured design on its surface. the bracelet features a silver', 'the image portrays a young woman dressed in armor with a unique design. she is holding a small object', 'the image captures a serene night scene at a beach with calm waters, reflecting the light of the moon', 'the image captures a serene outdoor setting at dusk, featuring a large dome structure with a central dome at', 'the image captures a lively scene inside a large office building with multiple desks and computers. the room', 'the image captures a bustling city scene with a bustling building with multiple balconies on its', 'the image captures a young girl holding a red apple with a green leaf on its tip, which she', 'the image captures a moment inside a car with a man smiling at the camera. he is wearing a', "the image presents a vibrant illustration of a stylized arrow with a curved edge. the arrow ' s center", 'the image features a logo with a red triangle at the top of it. the logo is prominently displayed', 'the image presents a vibrant scene from a historical period where two men are engaged in battle, one on', 'the image portrays a man with a beard and mustache, wearing a white shirt with a collar and a', 'the image portrays a lively scene from a medieval manuscript with a central focus on a group of people,', 'the image presents three glasses filled with wine and various food items. the glasses are placed on a wooden', 'the image showcases a close - up view of a light green shirt with a collar and a button closure', 'the image portrays three women with short ha ...

# %%
# Calculate ROUGE scores
rouge_result = rouge.compute(predictions=predictions, references=references)
print("ROUGE:")
for k, v in rouge_result.items():
    print(f"{k}: {v:.4f}")

bleu_result = bleu.compute(predictions=predictions, references=references)
print("\nBLEU:")
print(f"BLEU: {bleu_result['bleu']:.4f}")
# Out:
# ROUGE:
# rouge1: 0.2275
# rouge2: 0.1230
# rougeL: 0.1989
# rougeLsum: 0.1988
#
# BLEU:
# BLEU: 0.0017
